# %%
import pandas as pd
from data_viz_alapok import uci_adult as uci
import importlib as imp
imp.reload(uci)
# Out:
# <module 'data_viz_alapok.uci_adult' from '/home/karpatika/BCE_NETWORK/bce_ep_2021/data_viz_alapok/uci_adult.py'>

# %%
adult_data = uci.read_data()

# %%
uci.plot_education_against_tv(adult_data)

# %%
uci.create_hours_income_plot(adult_data)
